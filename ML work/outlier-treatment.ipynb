# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat           dlf regal gardens   sector 90   1.30
# 1          flat               tata primanti   sector 72   3.25
# 2          flat  ramprastha the edge towers  sector 37d   0.80
# 3          flat      m3m golf hills phase 1   sector 79   1.70
# 4          flat                 ss the leaf   sector 85   1.12
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7150.0  1818.0  Super Built up area 1818(168.9 sq.m.)Built Up ...
# 1         10545.0  3082.0             Super Built up area 3300(306.58 sq.m.)
# 2          5797.0  1380.0  Super Built up area 1380(128.21 sq.m.)Built Up...
# 3         10828.0  1570.0  Built Up area: 1570 (145.86 sq.m.)Carpet area:...
# 4          6453.0  1736.0  Super Built up area 1741(161.74 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 2030         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 1234         house                                        independent
# 2199         house                                        independent
# 3683         house                                     dlf city plots
# 1118         house                                   suncity township
# 770          house                             emaar the palm springs
# 159          house                                        independent
# 1290         house                                 vipul tatvam villa
# 219          house                                     dlf city plots
# 3530         house                             luxury dlf city floors
# 752          house                                        independent
# 2811         house                                 vipul tatvam villa
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 301          house  project housing board colony        sector 31   8.00
# 770          house        emaar the palm springs        sector 54  24.00
# 1339         house            emaar mgf marbella        sector 66  18.00
# 1348         house            cloudnine cottages  sohna road road   5.50
# 1583          flat                unitech vistas        sector 70   9.00
# 1839         house                unitech escape        sector 50  10.80
# 2150         house                  malibu towne        sector 47   8.50
# 2199         house                   independent        sector 26  26.00
# 2424         house                   independent        sector 26  14.75
# 2779         house        emaar the palm springs        sector 54  14.00
# 3414         house                           nul        sector 28  12.50
# 3683         house                dlf city plots        sector 26  26.00
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 53            flat          hcbs sports ville  sohna road   0.35
# 389           flat      signature the roselia   sector 95   0.45
# 448           flat  signature global solera 2  sector 107   0.51
# 1295         house                independent   sector 50   5.00
# 2516          flat            ramsons kshitij   sector 95   0.31
#
#       price_per_sqft      area                           areaWithType  \
# 53               4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 389              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 448              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1295           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 2516             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 53          2         2       2       8.0         NaN  Relatively New
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 1209, 1921, 3653, 1824, 2767, 617, 672, 98, 2981
# Out:
#      property_type                    society           sector  price  \
# 1209         house                independent        sector 26  18.40
# 1405         house  ganpati heights apartment        sector 13   1.25
# 1921          flat                 rof ananda        sector 95   0.38
# 3653          flat                 rof ananda        sector 95   0.38
# 1593         house      dlf city plot phase 4        sector 28  13.00
# 1824          flat              pyramid elite        sector 86   0.46
# 2767          flat                 rof ananda        sector 95   0.33
# 617           flat      signature the serenas       sohna road   0.28
# 416          house                independent        sector 25   7.30
# 672           flat            ramsons kshitij        sector 95   0.24
# 98            flat                 rof ananda        sector 95   0.21
# 3264         house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[1209, 1921, 3653, 1824, 2767, 617, 672, 98, 2981], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 1405         house  ganpati heights apartment        sector 13   1.25
# 1593         house      dlf city plot phase 4        sector 28  13.00
# 416          house                independent        sector 25   7.30
# 3264         house                independent        sector 57   6.25
# 3546         house                independent        sector 43   5.50
# 2692          flat                 godrej air        sector 85   2.50
# 2786         house       unitech aspen greens        sector 50   6.95
# 3114          flat                godrej icon       sector 88a   1.75
# 1234         house                independent        sector 43  27.50
# 2291          flat             m3m golfestate        sector 65  13.20
# 1912         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 1405           151.0  82781.0
# 1593          1992.0  65261.0
# 416           1560.0  46795.0
# ...

# %%
df.loc[1405,'area'] = 115*9
df.loc[1593,'area'] = 7250
df.loc[416,'area'] = 5800
df.loc[3264,'area'] = 2660
df.loc[3546,'area'] = 2850
df.loc[2692,'area'] = 1812
df.loc[2786,'area'] = 2160
df.loc[3114,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 1177         house                  independent   sector 54   5.00
# 1944         house                  independent   sector 43   4.50
# 3496         house                  independent  sector 17a   3.87
# 1059         house                  independent  sector 17a   3.93
# 191          house                private house   sector 55   7.05
# 2028         house                  independent   sector 54   5.50
# 219          house               dlf city plots   sector 26  20.00
# 225          house                  independent   sector 11   4.50
# 2097         house                  independent   sector 55   9.19
# 3538         house                  independent   sector 43  13.50
# 3530         house       luxury dlf city floors   sector 26  20.00
# 2252         house                  independent   sector 56  12.39
# 762          house                  independent   sector 40  12.00
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3309         house  adani brahma samsara  sector 60  18.02         28200.0
# 1549         house           independent  sector 24  11.00         28902.0
# 3442         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 3309  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 1549  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 3442  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3309        12      3+       3.0  North-East  Relatively New
# 1549        11      3+       3.0        East    Old Property
# 3442        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat           dlf regal gardens   sector 90   1.30
# 1          flat               tata primanti   sector 72   3.25
# 2          flat  ramprastha the edge towers  sector 37d   0.80
# 3          flat      m3m golf hills phase 1   sector 79   1.70
# 4          flat                 ss the leaf   sector 85   1.12
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7150.0  1818.0  Super Built up area 1818(168.9 sq.m.)Built Up ...
# 1         10545.0  3082.0             Super Built up area 3300(306.58 sq.m.)
# 2          5797.0  1380.0  Super Built up area 1380(128.21 sq.m.)Built Up...
# 3         10828.0  1570.0  Built Up area: 1570 (145.86 sq.m.)Carpet area:...
# 4          6453.0  1736.0  Super Built up area 1741(161.74 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 513           flat       krrish provence estate  gwal pahari    7.5
# 2687          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 513           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 2687          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 513         5         6      3+      23.0  North-East  Relatively New
# 2687        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 513               10000.0            NaN          NaN           0
# 2687               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 1234         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1234  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1234  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1234          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 1234                1            42

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2291          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 2692          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2291  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 2692  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 2291       North      Moderately Old                  NaN            NaN
# 2692  North-East  Under Construction                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2291      11000.0           0             1           0           0       0
# 2692      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[2692,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2291          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2291  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 2291  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 2291           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 2291                0            60

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat           dlf regal gardens   sector 90   1.30
# 1          flat               tata primanti   sector 72   3.25
# 2          flat  ramprastha the edge towers  sector 37d   0.80
# 3          flat      m3m golf hills phase 1   sector 79   1.70
# 4          flat                 ss the leaf   sector 85   1.12
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7150.0  1818.0  Super Built up area 1818(168.9 sq.m.)Built Up ...
# 1         10545.0  3082.0             Super Built up area 3300(306.58 sq.m.)
# 2          5797.0  1380.0  Super Built up area 1380(128.21 sq.m.)Built Up...
# 3         10828.0  1570.0  Built Up area: 1570 (145.86 sq.m.)Carpet area:...
# 4          6453.0  1736.0  Super Built up area 1741(161.74 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat           dlf regal gardens   sector 90   1.30
# 1          flat               tata primanti   sector 72   3.25
# 2          flat  ramprastha the edge towers  sector 37d   0.80
# 3          flat      m3m golf hills phase 1   sector 79   1.70
# 4          flat                 ss the leaf   sector 85   1.12
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7151.0  1818.0  Super Built up area 1818(168.9 sq.m.)Built Up ...
# 1         10545.0  3082.0             Super Built up area 3300(306.58 sq.m.)
# 2          5797.0  1380.0  Super Built up area 1380(128.21 sq.m.)Built Up...
# 3         10828.0  1570.0  Built Up area: 1570 (145.86 sq.m.)Carpet area:...
# 4          6452.0  1736.0  Super Built up area 1741(161.74 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 752          house                   independent   sector 26   20.0
# 764          house                   independent   sector 28   12.0
# 954          house                   independent   sector 43    9.5
# 1322         house                   independent   sector 26   19.0
# 1452         house                   independent   sector 25   13.0
# 1503         house                dlf city plots   sector 26   19.0
# 1766         house                   independent   sector 55    5.0
# 1778         house                   independent  sector 105    9.9
# 1978         house  sushant lok 1 builder floors   sector 43   13.0
#
#       price_per_sqft    area  \
# 752          44444.0  4500.0
# 764          42194.0  2844.0
# 954          42222.0  2250.0
# 1322         42222.0  4500.0
# 1452         45710.0  2844.0
# 1503         42054.0  4518.0
# 1766         44444.0  1125.0
# 1778         49500.0  2000.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 250.5

# %%
df[(df['area']/df['bedRoom'])<250]
# Out:
#      property_type                           society      sector  price  \
# 8            house                       independent   sector 45   4.49
# 10            flat                     prime habitat  sector 99a   0.27
# 35            flat                   ramsons kshitij   sector 95   0.40
# 47            flat                        mvn athens  sohna road   0.26
# 73            flat  signature global the millennia 3  sector 37d   0.50
# ...            ...                               ...         ...    ...
# 3730         house                       independent    sector 4   0.67
# 3750         house                       independent    sector 7   1.16
# 3751         house  nirmal enclave, maruti kunj road   sector 11   0.24
# 3752         house                       independent  sector 105   0.35
# 3792         house                   naman residency    sector 4   0.50
#
#       price_per_sqft    area  \
# 8            24455.0  1836.0
# 10            5433.0   497.0
# ...

# %%
df[(df['area']/df['bedRoom'])<250].sample(5)
# Out:
#      property_type                   society      sector  price  \
# 1863         house               independent   sector 13   1.50
# 1955          flat  breez global heights 88a  sector 88a   0.50
# 529          house                 jacobpura   sector 12   0.53
# 2465         house               independent   sector 28   0.45
# 396          house               independent    sector 2   1.15
#
#       price_per_sqft    area                    areaWithType  bedRoom  \
# 1863         11538.0  1300.0    Plot area 1300(120.77 sq.m.)       10
# 1955          8375.0   597.0  Carpet area: 597 (55.46 sq.m.)        3
# 529          14601.0   363.0      Plot area 360(33.45 sq.m.)        4
# 2465         10000.0   450.0  Built Up area: 50 (4.65 sq.m.)        5
# 396          19360.0   594.0       Plot area 66(55.18 sq.m.)        3
#
#       bathroom balcony  floorNum      facing       agePossession  \
# 1863         7       3       4.0        East      Moderately Old
# ...

# %%
sns.lmplot(x='area',y='bedRoom',data=df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[df['area_room_ratio']<250].sort_values('area_room_ratio')
# Out:
#      property_type                          society  \
# 2846         house                      independent
# 1162         house  ashok vihar phase iii extension
# 1270         house                            ansal
# 3552         house                      independent
# 3131         house                      independent
# ...            ...                              ...
# 3691          flat            pyramid urban homes 2
# 2417          flat            pyramid urban homes 2
# 84            flat                      zara aavaas
# 10            flat                    prime habitat
# 562           flat          signature global solera
#
#                           sector  price  price_per_sqft   area  \
# 2846                   sector 28   0.75         20833.0  360.0
# 1162  sector 3 phase 3 extension   0.40          8889.0  450.0
# 1270                   sector 43   1.85         34259.0  540.0
# 3552                  sector 105   0.60         11111.0  540.0
# ...

# %%
df[df['area_room_ratio']<250].shape
# Out:
# (185, 24)

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 4     17
# 6     17
# 9     15
# 8     12
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df= df[df['area_room_ratio']>100]

# %%
outliers_df = df[(df['area_room_ratio']<250) & (df['bedRoom']>3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_11268\3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[df['area_room_ratio']<250].sort_values('area_room_ratio')
# Out:
#      property_type                                 society      sector  price  \
# 609          house                             independent    sector 7   0.27
# 3121         house                             independent   sector 17   0.32
# 1856         house  surendra homes dayaindependentd colony    sector 6   0.75
# 1157         house                             independent    sector 2   0.98
# 1895         house                    bhim nagar, sector 6    sector 6   0.85
# ...            ...                                     ...         ...    ...
# 2417          flat                   pyramid urban homes 2   sector 86   0.42
# 3691          flat                   pyramid urban homes 2   sector 86   0.41
# 84            flat                             zara aavaas  sector 104   0.49
# 10            flat                           prime habitat  sector 99a   0.27
# 562           flat                 signature global solera  sector 107   0.28
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)]
# Out:
#      property_type               society            sector  price  \
# 537          house           independent           manesar   1.10
# 794          house           independent  sector 3 phase 2   1.10
# 1157         house           independent          sector 2   0.98
# 1895         house  bhim nagar, sector 6          sector 6   0.85
# 1998         house           independent        sector 105   1.10
# 2236         house           independent           manesar   0.80
# 2546         house              shivpuri          sector 7   2.80
# 2547         house           independent          sector 7   1.16
# 2656         house           independent         sector 12   2.50
# 2778         house           independent         sector 11   3.50
# 3121         house           independent         sector 17   0.32
# 3378         house           independent  sector 3 phase 2   0.85
# 3469         house           independent         sector 12   0.65
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)].shape
# Out:
# (13, 24)

# %%
sns.lmplot(x='area',y='bedRoom',data=df)

# %%
df = df[~((df['area_room_ratio']<250) & (df['bedRoom']>4))]

# %%
sns.lmplot(x='area',y='bedRoom',data=df)

# %%
df.shape
# Out:
# (3555, 24)

# %%
df.to_csv('gurgaon_properties_outlier_treated.csv',index=False)
