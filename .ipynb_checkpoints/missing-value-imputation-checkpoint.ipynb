# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_outlier_treated.csv')

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat           dlf regal gardens   sector 90   1.30
# 1          flat               tata primanti   sector 72   3.25
# 2          flat  ramprastha the edge towers  sector 37d   0.80
# 3          flat      m3m golf hills phase 1   sector 79   1.70
# 4          flat                 ss the leaf   sector 85   1.12
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7151.0  1818.0  Super Built up area 1818(168.9 sq.m.)Built Up ...
# 1         10545.0  3082.0             Super Built up area 3300(306.58 sq.m.)
# 2          5797.0  1380.0  Super Built up area 1380(128.21 sq.m.)Built Up...
# 3         10828.0  1570.0  Built Up area: 1570 (145.86 sq.m.)Carpet area:...
# 4          6452.0  1736.0  Super Built up area 1741(161.74 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 0        3         3      3+       7.0       South  Relatively New
# 1        3         3       3       2.0       South  Moderately Old
# 2        2         2       3       2.0  North-East  Relatively New
# 3        3         2       3      10.0         NaN       Undefined
# 4        2         2       3      10.0        East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1818.0         1700.0       1400.0           0             0
# 1               3300.0            NaN          NaN           0             1
# 2               1380.0         1300.0       1200.0           0             0
# 3                  NaN         1570.0       1099.0           0             0
# 4               1741.0         1485.0       1335.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           0       0                0           141
# 1           0           0       0                0            94
# 2           0           0       0                0            78
# 3           0           0       0                0             0
# 4           0           0       1                0            49
#
#    area_room_ratio
# 0       606.000000
# 1      1027.333333
# 2       690.000000
# 3       523.333333
# 4       868.000000

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area          1968
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# ### Built up area

# %%
sns.scatterplot(x=df['built_up_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x=df['built_up_area'],y=df['carpet_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3550    False
# 3551    False
# 3552    False
# 3553    False
# 3554    False
# Length: 3555, dtype: bool

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (531, 24)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio, carpet_to_built_up_ratio)
# Out:
# 1.105263157894737 0.9

# %%
# both present built up null
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                         society      sector  price  \
# 15          flat        signature andour heights   sector 71   0.60
# 18          flat          experion the heartsong  sector 108   1.30
# 23          flat         shree vardhman victoria   sector 70   1.63
# 30          flat  ramson kshitij sec-95 gurugram   sector 95   0.27
# 35          flat                  vatika gurgaon   sector 83   1.25
#
#     price_per_sqft    area                                       areaWithType  \
# 15         10000.0   600.0  Super Built up area 600(55.74 sq.m.)Carpet are...
# 18          8344.0  1558.0  Super Built up area 1758(163.32 sq.m.)Carpet a...
# 23          8359.0  1950.0  Super Built up area 1950(181.16 sq.m.)Carpet a...
# 30          2700.0  1000.0  Super Built up area 1000(92.9 sq.m.)Carpet are...
# 35          7812.0  1600.0  Super Built up area 2390(222.04 sq.m.)Carpet a...
#
#     bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 15        2         2       1       5.0  South-West  Relatively New
# 18        3         3      3+       7.0  South-West  Relatively New
# 23        3         5       3      12.0        East  Relatively New
# 30        2         2       0       1.0        West       Undefined
# 35        4         4       3      12.0  South-West  Moderately Old
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 15                600.0            NaN        514.0           0             0
# 18               1758.0            NaN       1558.0           1             0
# 23               1950.0            NaN       1161.0           0             1
# 30               1000.0            NaN        550.0           0             0
# 35               2390.0            NaN       1600.0           0             1
#
#     store room  pooja room  others  furnishing_type  luxury_score  \
# 15           0           1       0                0            59
# 18           0           0       0                0           150
# 23           0           0       0                0            43
# 30           0           0       0                0             0
# 35           0           0       0                0           103
#
#     area_room_ratio
# 15       300.000000
# 18       519.333333
# 23       650.000000
# 30       500.000000
# 35       400.000000

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\1215074969.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\1215074969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area          1547
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb present c is null built up null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                     society      sector  price  \
# 1           flat               tata primanti   sector 72   3.25
# 7           flat      vatika the seven lamps   sector 82   0.85
# 9           flat         mapsko royale ville   sector 82   0.99
# 12          flat  ramprastha the edge towers  sector 37d   1.00
# 14          flat            puri emerald bay  sector 104   1.58
#
#     price_per_sqft    area                            areaWithType  bedRoom  \
# 1          10545.0  3082.0  Super Built up area 3300(306.58 sq.m.)        3
# 7           6538.0  1300.0  Super Built up area 1300(120.77 sq.m.)        2
# 9           5531.0  1790.0   Super Built up area 1790(166.3 sq.m.)        3
# 12          5650.0  1770.0  Super Built up area 1770(164.44 sq.m.)        3
# 14          9117.0  1733.0  Super Built up area 1700(157.94 sq.m.)        2
#
#     bathroom balcony  floorNum      facing   agePossession  \
# 1          3       3       2.0       South  Moderately Old
# 7          2       2       0.0        East  Relatively New
# 9          4       2      14.0  South-West    New Property
# 12         3      3+      13.0         NaN  Moderately Old
# 14         3       3      11.0  North-East  Relatively New
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 1                3300.0            NaN          NaN           0             1
# 7                1300.0            NaN          NaN           0             0
# 9                1790.0            NaN          NaN           0             1
# 12               1770.0            NaN          NaN           0             0
# 14               1700.0            NaN          NaN           0             1
#
#     store room  pooja room  others  furnishing_type  luxury_score  \
# 1            0           0       0                0            94
# 7            0           0       0                1            49
# 9            0           0       0                0            95
# 12           0           0       0                0            38
# 14           0           0       0                0           101
#
#     area_room_ratio
# 1       1027.333333
# 7        650.000000
# 9        596.666667
# 12       590.000000
# 14       866.500000

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area           672
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb null c is present built up null
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#    property_type                       society      sector  price  \
# 10          flat                 prime habitat  sector 99a   0.27
# 17          flat     signature global city 63a  sector 63a   1.40
# 21          flat         pyramid urban homes 2   sector 86   0.41
# 31          flat                    lotus homz  sector 111   0.60
# 33          flat  railway officers rpf society   sector 9a   1.25
#
#     price_per_sqft    area                      areaWithType  bedRoom  \
# 10          5433.0   497.0    Carpet area: 497 (46.17 sq.m.)        2
# 17         11336.0  1235.0  Carpet area: 1235 (114.74 sq.m.)        2
# 21          6902.0   594.0    Carpet area: 601 (55.83 sq.m.)        2
# 31          8451.0   710.0    Carpet area: 710 (65.96 sq.m.)        2
# 33          6921.0  1806.0  Carpet area: 1806 (167.78 sq.m.)        4
#
#     bathroom balcony  floorNum      facing       agePossession  \
# 10         2       1       4.0  North-East        New Property
# 17         2       2       3.0        East  Under Construction
# 21         2       1       3.0        West      Relatively New
# 31         2       3       9.0        East        New Property
# 33         3       3       1.0         NaN        Old Property
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 10                  NaN            NaN        497.0           0             0
# 17                  NaN            NaN       1235.0           0             0
# 21                  NaN            NaN        601.0           0             0
# 31                  NaN            NaN        710.0           0             0
# 33                  NaN            NaN       1806.0           0             1
#
#     store room  pooja room  others  furnishing_type  luxury_score  \
# 10           0           0       0                0             7
# 17           0           0       1                0             0
# 21           0           0       0                0            63
# 31           0           0       0                0            52
# 33           0           0       0                0            40
#
#     area_room_ratio
# 10            248.5
# 17            617.5
# 21            297.0
# 31            355.0
# 33            451.5

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\2136919732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area             0
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 2442   9.50  4071.0          500.0
# 874    2.58  2200.0         1991.0
# 801    4.75  2367.0          261.0
# 2042   3.10  1548.0         1548.0
# 523   11.75  5056.0          502.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                     society      sector  price  \
# 0          flat           dlf regal gardens   sector 90   1.30
# 1          flat               tata primanti   sector 72   3.25
# 2          flat  ramprastha the edge towers  sector 37d   0.80
# 3          flat      m3m golf hills phase 1   sector 79   1.70
# 4          flat                 ss the leaf   sector 85   1.12
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 0          7151.0        3         3      3+       7.0       South
# 1         10545.0        3         3       3       2.0       South
# 2          5797.0        2         2       3       2.0  North-East
# 3         10828.0        3         2       3      10.0         NaN
# 4          6452.0        2         2       3      10.0        East
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0  Relatively New         1700.0           0             0           0
# 1  Moderately Old         2986.0           0             1           0
# 2  Relatively New         1300.0           0             0           0
# 3       Undefined         1570.0           0             0           0
# 4  Relatively New         1485.0           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                0           141
# 1           0       0                0            94
# 2           0       0                0            78
# 3           0       0                0             0
# 4           0       1                0            49

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum             17
# facing             1011
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                  society             sector  price  \
# 131          house              independent           sector 4   0.65
# 326          house       vipul tatvam villa          sector 48   8.50
# 519          house              independent           sector 3   1.50
# 862          house               jacob pura          sector 12   0.35
# 898           flat       experion heartsong  dwarka expressway   1.08
# 1190         house        ansal sushant lok          sector 43  10.50
# 1391         house              independent          sector 25  13.00
# 1799         house              independent           sector 7   6.50
# 1801          flat                      NaN          sector 78   0.60
# 1812         house       emaar mgf marbella          sector 66   9.00
# 2553         house       vipul tatvam villa          sector 48   8.50
# 2599         house              independent          sector 24   1.45
# 2623         house              independent           sector 4   4.12
# 2716         house              independent           sector 2   5.60
# 2812         house              independent          sector 26   4.60
# 2879         house     dlf new town heights          sector 86   2.47
# 3526         house  ansal sushant lok plots          sector 43   3.30
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 131          11111.0        4         2       2       NaN         NaN
# 326          26235.0        4         4       1       NaN         NaN
# 519          10288.0        3         3       0       NaN         NaN
# 862           9722.0        2         1       0       NaN         NaN
# 898           6150.0        3         3       0       NaN         NaN
# 1190         27911.0        4         4       2       NaN  North-East
# 1391         45710.0        6         8      3+       NaN         NaN
# 1799         15046.0        3         2      3+       NaN         NaN
# 1801          3692.0        2         2       0       NaN         NaN
# 1812         21251.0        4         4      3+       NaN  South-West
# 2553         26235.0        4         4       2       NaN        East
# 2599          2984.0        3         3       1       NaN         NaN
# 2623          8889.0        2         1      3+       NaN         NaN
# 2716         17284.0        8         6      3+       NaN  South-West
# 2812         12198.0        4         4      3+       NaN         NaN
# 2879          7719.0        4         4      3+       NaN        West
# 3526         26570.0        1         1       0       NaN         NaN
#
#            agePossession  built_up_area  study room  servant room  store room  \
# 131       Moderately Old          585.0           0             0           0
# 326       Relatively New         3240.0           0             0           0
# 519         Old Property          210.0           0             0           0
# 862         Old Property          360.0           0             0           0
# 898   Under Construction         1758.0           0             0           0
# 1190        Old Property         3762.0           0             1           0
# 1391      Relatively New         2844.0           1             1           1
# 1799        Old Property         4320.0           0             0           0
# 1801  Under Construction         1625.0           0             0           0
# 1812      Relatively New         5200.0           0             1           1
# 2553      Moderately Old         3240.0           0             1           1
# 2599        Old Property          540.0           0             0           0
# 2623      Moderately Old         4635.0           0             0           0
# 2716      Moderately Old         3240.0           1             1           1
# 2812        Old Property         3771.0           0             0           0
# 2879      Moderately Old         2800.0           0             1           0
# 3526  Under Construction         1242.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 131            0       0                0             0
# 326            0       0                0            21
# 519            0       0                0             0
# 862            0       0                0             0
# 898            0       0                0             0
# 1190           0       0                0            59
# 1391           1       0                2             0
# 1799           0       0                0             9
# 1801           0       0                0             0
# 1812           1       0                1           114
# 2553           1       0                0            88
# 2599           0       0                0             9
# 2623           0       0                0             0
# 2716           1       0                0             0
# 2812           0       0                0            28
# 2879           1       0                1           130
# 3526           0       0                0             0

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# 2.0

# %%
df['floorNum'].fillna(2.0,inplace=True)
# Out:
# C:\Users\FARHAN NAUSHAD\AppData\Local\Temp\ipykernel_17148\15612474.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1011
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### facing

# %%
1011/df.shape[0]
# Out:
# 0.2843881856540084

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                  society      sector  price  \
# 1935          flat   krrish florence estate   sector 70   1.30
# 3038          flat  sare green parc phase 3   sector 92   0.79
# 758          house               ardee city   sector 52   2.25
# 3304          flat      trisara our homes 3  sohna road   0.38
# 1825          flat               bptp terra  sector 37d   1.75
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum       agePossession  \
# 1935          5601.0        3         3       3      17.0  Under Construction
# 3038          6086.0        3         2       2      15.0        New Property
# 758          16071.0        3         3       3       4.0        New Property
# 3304          6312.0        2         2       2       1.0           Undefined
# 1825          7987.0        4         4       3       7.0      Relatively New
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 1935         1865.0           0             0           0           0       0
# 3038         1175.0           0             0           0           0       0
# 758          1800.0           0             1           0           0       0
# 3304          602.0           0             0           0           0       0
# 1825         2100.0           0             0           0           0       1
#
#       furnishing_type  luxury_score
# 1935                1            61
# 3038                0            29
# 758                 1            22
# 3304                0             0
# 1825                1           120

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft  bedRoom  \
# 1801          flat     NaN  sector 78    0.6          3692.0        2
#
#       bathroom balcony  floorNum       agePossession  built_up_area  \
# 1801         2       0       2.0  Under Construction         1625.0
#
#       study room  servant room  store room  pooja room  others  \
# 1801           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 1801                0             0

# %%
df.drop(index=[1801],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ### agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1605
# New Property           557
# Moderately Old         545
# Old Property           293
# Undefined              291
# Under Construction     263
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                       society      sector  price  \
# 3             flat        m3m golf hills phase 1   sector 79   1.70
# 6             flat  railway officers rpf society   sector 9a   1.30
# 24            flat                       elevate   sector 50   6.75
# 25            flat             mapsko casa bella   sector 82   1.75
# 28            flat                    chintamani  sector 103   1.57
# ...            ...                           ...         ...    ...
# 3473         house                   independent  sector 105   0.55
# 3478          flat            emaar palm gardens   sector 83   1.80
# 3493          flat         signature global park  sohna road   0.55
# 3511         house                   independent  sector 105   0.35
# 3536          flat                    godrej air   sector 85   1.75
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 3            10828.0        3         2       3      10.0     Undefined
# 6             5039.0        4         4      3+       9.0     Undefined
# 24           19882.0        4         4       0      10.0     Undefined
# 25            6903.0        4         5      3+       1.0     Undefined
# 28            8509.0        3         3       3       1.0     Undefined
# ...              ...      ...       ...     ...       ...           ...
# 3473         10913.0        2         4       0       2.0     Undefined
# 3478          9474.0        3         4       0       9.0     Undefined
# 3493          6691.0        2         2       3       3.0     Undefined
# 3511          7778.0        2         2       1       2.0     Undefined
# 3536          9589.0        3         3       2      27.0     Undefined
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 3            1570.0           0             0           0           0       0
# 6            2580.0           0             0           0           0       0
# 24           3395.0           0             0           0           0       0
# 25           2535.0           0             0           0           0       0
# 28           1845.0           0             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3473           56.0           0             0           0           0       0
# 3478         1900.0           0             0           0           0       0
# 3493          913.0           0             0           0           0       0
# 3511          556.0           0             0           0           0       0
# 3536         1825.0           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 3                   0             0
# 6                   0             0
# 24                  0             0
# 25                  0            54
# 28                  0             0
# ...               ...           ...
# 3473                0             0
# 3478                0            55
# 3493                0            58
# 3511                0             0
# 3536                0            44
#
# [291 rows x 18 columns]

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1717
# New Property           597
# Moderately Old         584
# Old Property           326
# Under Construction     277
# Undefined               53
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1726
# New Property           598
# Moderately Old         591
# Old Property           329
# Under Construction     277
# Undefined               33
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1728
# Moderately Old         622
# New Property           598
# Old Property           329
# Under Construction     277
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.shape
# Out:
# (3554, 18)

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)
